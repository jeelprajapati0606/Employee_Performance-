# %% [markdown]
# # Employee Performance

# %% [markdown]
# ## PART - B Practical

# %% [markdown]
# ## Import Libraries :

# %%
import numpy as np
import pandas as pd
from statistics import mode

# %% [markdown]
# ## Load Dataset :

# %%
data = pd.read_csv("employee_performance.csv")
data
# Out:
#      Employee_ID  Department  Age  Salary  Projects_Completed  Working_Hours  \
# 0       EMP00001  Operations   28   28278                   8           37.3
# 1       EMP00002          HR   27  113696                  17           32.6
# 2       EMP00003          HR   22   37280                   6           37.0
# 3       EMP00004          IT   56   51062                  20           51.0
# 4       EMP00005     Support   49  102236                   8           54.3
# ...          ...         ...  ...     ...                 ...            ...
# 3995    EMP03996  Operations   49  134325                   2           39.9
# 3996    EMP03997       Sales   23   82135                  13           59.2
# 3997    EMP03998  Operations   48   60215                   2           32.2
# 3998    EMP03999  Operations   46  145080                  11           39.0
# 3999    EMP04000     Support   26  117285                   7           59.6
#
#       Performance_Score Promotion_Status
# ...
